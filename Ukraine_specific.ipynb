# %% [markdown]
# <a href="https://colab.research.google.com/github/Danddt/Russian_Opinion_Polls/blob/main/Ukraine_specific.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Zoom into Ukraine wars
#
# the expand when Russia goes to war: data on dips in GDP Vs coming conflict (diversion of founds from the economy), US president(Democrat Republican)

# %%
import pathlib
from datetime import date

date1 = str(date.today())

new_dir = pathlib.Path('/content/drive/MyDrive/RUSSdata/images/Ukraine/images', date1)
new_dir.mkdir(parents=True, exist_ok=True)

# %%
work_date = '2022-09-30'
date=work_date[:-3]
date
# Out:
# '2022-09'

# %%
content = '/content/drive/MyDrive/RUSSdata/Levada/'

# %%
president_approval= pd.read_csv(content+work_date+'/Levada_Putin’s approval rating.csv')
president_approval['date'] = pd.to_datetime(president_approval['date'].str.strip(), format='%Y-%m')

ukraine_phase2_pres = president_approval[(president_approval['date'] >= '2022-1') & (president_approval['date'] <= date)]
ukraine_phase1_pres = president_approval[(president_approval['date'] >= '2014-1') & (president_approval['date'] <= '2014-09')]

ukraine_phase2_pres['month']=ukraine_phase2_pres['date'].dt.month
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
ukraine_phase2_pres.tail(3)
# Out:
#           date  Approve  Disapprove  No answer  month
# 273 2022-07-01     83.0        15.0        2.0      7
# 274 2022-08-01     83.0        15.0        2.0      8
# 275 2022-09-01     77.0        21.0        2.0      9

# %%
ukraine_phase1_pres['month']=ukraine_phase1_pres['date'].dt.month
ukraine_phase1_pres.tail(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           date  Approve  Disapprove  No answer  month
# 179 2014-07-01     85.0        14.0        1.0      7
# 180 2014-08-01     84.0        15.0        1.0      8
# 181 2014-09-01     86.0        14.0        1.0      9

# %%
goverment_approval = pd.read_csv(content+work_date+'/Levada_Approval of the government.csv')
goverment_approval['date'] = pd.to_datetime(goverment_approval['date'].str.strip(), format='%Y-%m')

ukraine_phase2_gov = goverment_approval[(goverment_approval['date'] >= '2022-1') & (goverment_approval['date'] <= date)]
ukraine_phase2_gov['month']=ukraine_phase2_gov['date'].dt.month

ukraine_phase1_gov = goverment_approval[(goverment_approval['date'] >= '2014-1') & (goverment_approval['date'] <= '2014-9')]
ukraine_phase1_gov['month']=ukraine_phase1_gov['date'].dt.month
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(ukraine_phase1_gov.month,ukraine_phase1_gov['Approve'],linewidth=3,linestyle='dashed', color='red' )
plt.plot(ukraine_phase2_gov.month, ukraine_phase2_gov['Approve'], linewidth=3, color='red' )

plt.axvline(2,color='black',linestyle='dashed', alpha=0.8)
plt.text(x=2, y=80, s=' 2014 \n invasion,\n \n 2022 \n invasion', color='black')

plt.ylim(30,100, 10)
positions = (2, 3, 4, 5, 6,7, 8,9)
positions = (2, 3, 4, 5, 6,7, 8,9)
labels = ('February', 'March', 'April', 'May', 'June', 'July', 'August', 'September')
plt.legend(['Government Approval: 2014', 'Government: 2022'], loc='lower right')
plt.xticks(positions, labels)
plt.title('Approval of the Governmentt during the Ukrainian War 2014 and 2022')
plt.savefig(str(new_dir)+ '/gov_approval_ratings.jpg')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(ukraine_phase1_pres.month,ukraine_phase1_pres['Approve'],linewidth=3,linestyle='dashed', color='blue' )
plt.plot(ukraine_phase2_pres.month, ukraine_phase2_pres['Approve'], linewidth=3, color='blue' )

plt.axvline(2,color='black',linestyle='dashed', alpha=0.8)
plt.text(x=2, y=50, s=' 2014 \n invasion,\n \n 2022 \n invasion', color='black')

plt.ylim(30,100, 10)
positions = (2, 3, 4, 5, 6,7, 8,9)
positions = (2, 3, 4, 5, 6,7, 8,9)
labels = ('February', 'March', 'April', 'May', 'June', 'July', 'August','September')
plt.legend(['President Approval: 2014', 'President: 2022'], loc='lower right')
plt.xticks(positions, labels)
plt.title('Approval of the President during the Ukrainian War 2014 and 2022')
plt.savefig(str(new_dir)+ '/pres_approval_ratings.jpg')

# %%
move = pd.read_csv(content+work_date+'/Levada_Assessment of situation in the country.csv')
move['date'] = pd.to_datetime(move['date'].str.strip(), format='%Y-%m')
ukraine_phase2_move =  move[(move['date'] >= '2022-1') & (move['date'] <= '2022-9')]
ukraine_phase2_move['month']=ukraine_phase2_move['date'].dt.month
ukraine_phase2_move.tail(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#           date  In the right direction  On the wrong track  \
# 304 2022-07-01                    68.0                22.0
# 305 2022-08-01                    67.0                24.0
# 306 2022-09-01                    60.0                27.0
#
#      Difficult to answer  month
# 304                 10.0      7
# 305                  9.0      8
# 306                 12.0      9

# %%
ukraine_phase1_move = move[(move['date'] >= '2014-1') & (move['date'] <= '2014-9')]
ukraine_phase1_move['month']=ukraine_phase1_move['date'].dt.month
ukraine_phase1_move.tail(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           date  In the right direction  On the wrong track  \
# 209 2014-07-01                    55.0                26.0
# 210 2014-08-01                    64.0                22.0
# 211 2014-09-01                    62.0                22.0
#
#      Difficult to answer  month
# 209                 19.0      7
# 210                 14.0      8
# 211                 17.0      9

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.ylim(20,100, 10)
positions = (1,2, 3, 4, 5, 6,7, 8,9)
positions = (1,2, 3, 4, 5, 6,7, 8,9)
labels = ('January','February', 'March', 'April', 'May', 'June', 'July', 'August','September')
plt.xticks(positions, labels)
plt.plot(ukraine_phase1_move.month,ukraine_phase1_move['In the right direction'],linewidth=3,linestyle='dashed', color='darkviolet' )
plt.plot(ukraine_phase2_move.month, ukraine_phase2_move['In the right direction'], linewidth=3, color='darkviolet' )

plt.legend(['Russia Moving in the right direction\n: 2014', ':2022'], loc='lower right')
plt.title('Is Russia moving in the right direction?')
plt.savefig(str(new_dir)+ '/move_approval_ratings.jpg')

# %%
eu_att = pd.read_csv(content+work_date+'/Levada_Attitude to the EU.csv')
eu_att['date'] = pd.to_datetime(eu_att['date'].str.strip(), format='%Y-%m')

# %%
us_att = pd.read_csv(content+work_date+'/Levada_Attitude to the US.csv')
us_att['date'] = pd.to_datetime(us_att['date'].str.strip(), format='%Y-%m')

# %%
eu_2012 = eu_att[eu_att.date>'2012']
us_2012= us_att[us_att.date>'2012']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.ylim(0,100, 30)


plt.plot(us_2012.date, us_2012['Positive'], linewidth=3, color='yellowgreen' )
plt.plot(eu_2012.date,eu_2012['Positive'],linewidth=3, color='plum' )


plt.axvline(pd.Timestamp('2015'),linestyle='dashed', color='orange',linewidth = 10, alpha=.6)
plt.text(pd.Timestamp('2015'),y=70, s='First Ukraine War', horizontalalignment='center', color='black')
plt.axvline(pd.Timestamp('2022-05'),linestyle='dashed', linewidth = 10, color='dodgerblue',alpha=.6)
plt.text(pd.Timestamp('2022-05'),y=70, s='Second \nUkraine War', horizontalalignment='right', color='black')

plt.legend(['United States', 'European Union'], loc='lower left')
plt.title('Positive attitudes towards the United States and the European Union')
plt.savefig(str(new_dir)+ '/eu_us_ratings.jpg')

# %%
conflict = pd.read_csv('/content/drive/MyDrive/RUSSdata/wiki/2022-09-30/conflicts_russian_federation.csv')
conflict['datetime'] = pd.to_datetime(conflict['datetime'].str.strip(), format='%Y-%m')
conflict
# Out:
#     datetime  start      end                             Location  \
# 0 1999-08-01   1999     2009                             Chechnya
# 1 2008-08-01   2008      NaN  Georgia, South Ossetia and Abkhazia
# 2 2009-04-01   2009     2017                       North Caucasus
# 3 2014-02-01   2014  present               Ukraine (incl. Crimea)
# 4 2015-09-01   2015  present                                Syria
# 5 2018-08-01   2018  present             Central African Republic
# 6 2022-02-01   2022  ongoing                              Ukraine
#
#    month_start month_end  arb_val_war
# 0            8         4          100
# 1            8         8          100
# 2            4        12          100
# 3            2   ongoing          100
# 4            9   ongoing          100
# 5            8   ongoing          100
# 6            2   ongoing          100

# %% [markdown]
# "1 May 2004 – 10 new countries
#
# Cyprus and Malta join the EU along with 8 Central and Eastern European countries — Czechia, Estonia, Hungary, Latvia, Lithuania, Poland, Slovakia and Slovenia — finally ending the division of Europe after the Second World War."
#
# source: https://european-union.europa.eu/principles-countries-history/history-eu/2000-09_en
#
#
#
# "Date:	Major combat phase: 7 August 1999 – 30 April 2000, (8 months and 24 days)
# source: https://en.wikipedia.org/wiki/Second_Chechen_War

# %%
# LIST OF CONFLICTS UKRAINE RUSSIA

import pandas as pd
import numpy as np

link = "https://en.wikipedia.org/wiki/List_of_wars_involving_Ukraine"
tables = pd.read_html(link)

#data= tables[2].iloc[1:]

# %%
listo = []
for item in range(1, 8):
  listo.append(tables[item])

# %%
complete = pd.concat(listo)

# %%
clean =complete.reset_index().drop(['index'], axis=1)

# %%
# if column contains : Russian, Russia, Soviet
mylist = ['Russian', 'Russia', 'Soviet']
pattern = '|'.join(mylist)

clean_short =clean[clean['Combatant 2'].str.contains(pattern)]

# %%
clean_short['Date'] = clean_short['Date'].str.split(' ', expand=True).drop([1,2], axis=1)
clean_short
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             Date                                           Conflict  \
# 52          1659                                     Bohun Uprising
# 55          1750                            Haidamak Uprising, 1750
# 56     1768–1769                                      Koliivshchyna
# 67     1558–1583                                       Livonian War
# 72     1658–1659  Russo-Ukrainian / Moscovian-Cossack war Battle...
# 74     1655–1660                         Second Northern War Deluge
# 81     1700–1721               Great Northern War Battle of Poltava
# ...

# %%
clean_short = clean_short.sort_values(by='Date')
clean_short_short = clean_short[['Date', 'Conflict']]

# %%
clean_short_short.reset_index().drop(columns=['index'])
# Out:
#             Date                                           Conflict
# 0      1558–1583                                       Livonian War
# 1      1655–1660                         Second Northern War Deluge
# 2      1658–1659  Russo-Ukrainian / Moscovian-Cossack war Battle...
# 3           1659                                     Bohun Uprising
# 4      1700–1721               Great Northern War Battle of Poltava
# 5      1710–1711                               Pruth River Campaign
# 6           1750                            Haidamak Uprising, 1750
# 7      1768–1769                                      Koliivshchyna
# 8           1775                       the fall of Zaporizhian Sich
# 9      1917–1920                 Russian Civil War — Southern Front
# 10     1917–1921  Ukrainian War of Independence — Ukrainian–Sovi...
# 11     1918–1923                  Russian Civil War — Eastern Front
# 12     1919–1921  Polish–Soviet War (see also List of battles of...
# ...

# %%
clean_short_short.to_csv(str(new_dir)+ '/conflict_list.csv', index=False)
